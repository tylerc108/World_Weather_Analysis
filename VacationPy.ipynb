# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.29.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (5.1.0)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: pexpect>4.3 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: decorator in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (5.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (58.0.4)
# Requirement already satisfied: appnope in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: pygments in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (2.10.0)
# Requirement already satisfied: pickleshare in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: matplotlib-inline in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: backcall in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.11.0)
# Requirement already satisfied: jinja2 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: argon2-cffi in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.6)
# Requirement already satisfied: pycparser in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: testpath in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: bleach in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.0.0)
# Requirement already satisfied: defusedxml in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: async-generator in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: webencodings in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/tylercomerford/opt/anaconda3/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py) ... done
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=9c5665dcab686c8f0adc3c447cb489454ea5669367f6d40d673372a570cf91f6
#   Stored in directory: /Users/tylercomerford/Library/Caches/pip/wheels/66/ab/29/3032938612273665f0fa4d2fab4e3ecfe86480eaaa40aaee91
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City Country                 Date      Lat       Lng  \
# 0        0    Masvingo      ZW  2022-05-16 15:57:09 -20.0637   30.8277
# 1        1       Pelym      RU  2022-05-16 15:57:09  61.0108   61.9978
# 2        2  Hambantota      LK  2022-05-16 15:55:20   6.1241   81.1185
# 3        3     Mataura      NZ  2022-05-16 15:57:10 -46.1927  168.8643
# 4        4  Chokurdakh      RU  2022-05-16 15:57:11  70.6333  147.9167
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     62.65        67          75        6.91
# 1     53.28        59          46        1.41
# 2     79.14       100          20        9.22
# 3     56.48        95          74        1.86
# 4     24.69        96         100       12.03

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], dissipating=False, max_intensity=300, point_radius=4)# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent 
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country                 Date      Lat       Lng  \
# 2         2       Hambantota      LK  2022-05-16 15:55:20   6.1241   81.1185
# 5         5         Acapulco      MX  2022-05-16 15:55:39  16.8634  -99.8901
# 9         9            Potam      MX  2022-05-16 15:57:12  27.6000 -110.3833
# 10       10           Albany      US  2022-05-16 15:54:17  42.6001  -73.9662
# 14       14     Komsomolskiy      UZ  2022-05-16 15:57:14  40.4272   71.7189
# 18       18       Georgetown      MY  2022-05-16 15:56:19   5.4112  100.3354
# 22       22         Camacari      BR  2022-05-16 15:57:16 -12.6975  -38.3242
# 24       24  Bambous Virieux      MU  2022-05-16 15:57:17 -20.3428   57.7575
# 26       26        Cape Town      ZA  2022-05-16 15:53:24 -33.9258   18.4232
# 28       28          Rikitea      PF  2022-05-16 15:57:18 -23.1203 -134.9692
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 2      79.14       100          20        9.22
# 5      87.67        50          39        5.14
# 9      85.69        24         100        8.03
# 10     79.03        72          58        4.00
# 14     75.92        41          64        2.30
# 18     80.53        98          40        5.01
# 22     82.17        74          98        4.63
# 24     77.25        69          40       13.80
# 26     86.41        26           0        9.22
# 28     77.49        69          33       20.00

# %%
preferred_cities_df.count()
# Out:
# City_ID       187
# City          187
# Country       186
# Date          187
# Lat           187
# Lng           187
# Max Temp      187
# Humidity      187
# Cloudiness    187
# Wind Speed    187
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng Hotel Name
# 2        Hambantota      LK     79.14   6.1241   81.1185
# 5          Acapulco      MX     87.67  16.8634  -99.8901
# 9             Potam      MX     85.69  27.6000 -110.3833
# 10           Albany      US     79.03  42.6001  -73.9662
# 14     Komsomolskiy      UZ     75.92  40.4272   71.7189
# 18       Georgetown      MY     80.53   5.4112  100.3354
# 22         Camacari      BR     82.17 -12.6975  -38.3242
# 24  Bambous Virieux      MU     77.25 -20.3428   57.7575
# 26        Cape Town      ZA     86.41 -33.9258   18.4232
# 28          Rikitea      PF     77.49 -23.1203 -134.9692

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#                City Country  Max Temp      Lat       Lng  \
# 2        Hambantota      LK     79.14   6.1241   81.1185
# 5          Acapulco      MX     87.67  16.8634  -99.8901
# 9             Potam      MX     85.69  27.6000 -110.3833
# 10           Albany      US     79.03  42.6001  -73.9662
# 14     Komsomolskiy      UZ     75.92  40.4272   71.7189
# 18       Georgetown      MY     80.53   5.4112  100.3354
# 22         Camacari      BR     82.17 -12.6975  -38.3242
# 24  Bambous Virieux      MU     77.25 -20.3428   57.7575
# 26        Cape Town      ZA     86.41 -33.9258   18.4232
# 28          Rikitea      PF     77.49 -23.1203 -134.9692
#
#                                   Hotel Name
# 2                                Bungalow 63
# 5                  HS Hotsson Smart Acapulco
# 9                          Ejido La Pimienta
# 10
# 14                                 Ikathouse
# 18                            Cititel Penang
# 22                               Sítio Blasi
# 24                            Casa Tia Villa
# 26  Radisson Blu Hotel Waterfront, Cape Town
# 28                           People ThankYou

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
