# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Generating random latitude and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Adding the lats and longs to a list.
coordinates = list(lat_lngs)

# Creating list to hold cities.
cities = []
# Getting nearest city using citipy.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Add unique cities to the list w/ for loop.
    if city not in cities:
        cities.append(city)

# %%
# Add URL for API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "City Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | imbituba
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | russell
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | poum
# Processing Record 10 of Set 1 | pevek
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | maple creek
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | saint-pierre
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | asbe teferi
# Processing Record 22 of Set 1 | fukuma
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | naryan-mar
# Processing Record 25 of Set 1 | harper
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | yatou
# Processing Record 28 of Set 1 | angra
# City not found. Skipping...
# Processing Record 29 of Set 1 | guerrero negro
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | fukue
# Processing Record 33 of Set 1 | pasni
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | broome
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | lenoir city
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | kieta
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | binzhou
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | nouadhibou
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | englehart
# Processing Record 4 of Set 2 | hvolsvollur
# Processing Record 5 of Set 2 | haines junction
# Processing Record 6 of Set 2 | fort nelson
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | ambovombe
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | champerico
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | havre-saint-pierre
# Processing Record 14 of Set 2 | yulara
# Processing Record 15 of Set 2 | kahului
# Processing Record 16 of Set 2 | buchanan
# Processing Record 17 of Set 2 | sibolga
# Processing Record 18 of Set 2 | cintalapa
# Processing Record 19 of Set 2 | ketchikan
# Processing Record 20 of Set 2 | tongzi
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | mayo
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | prata
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | sao francisco de paula
# Processing Record 29 of Set 2 | maiduguri
# Processing Record 30 of Set 2 | halifax
# Processing Record 31 of Set 2 | yeniseysk
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | nanortalik
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | karratha
# Processing Record 39 of Set 2 | spiridonovka
# Processing Record 40 of Set 2 | bubaque
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | tawang
# Processing Record 43 of Set 2 | ayan
# Processing Record 44 of Set 2 | nynashamn
# Processing Record 45 of Set 2 | paipa
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | kikwit
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | la ronge
# Processing Record 5 of Set 3 | tahoua
# Processing Record 6 of Set 3 | langres
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | honggang
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | nampula
# Processing Record 11 of Set 3 | lindi
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | arica
# Processing Record 14 of Set 3 | tiznit
# Processing Record 15 of Set 3 | kyotera
# Processing Record 16 of Set 3 | turukhansk
# Processing Record 17 of Set 3 | rafaela
# Processing Record 18 of Set 3 | noumea
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | tocopilla
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | kununurra
# Processing Record 24 of Set 3 | acapulco
# Processing Record 25 of Set 3 | lancaster
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | shimoda
# Processing Record 31 of Set 3 | lompoc
# Processing Record 32 of Set 3 | jinchang
# Processing Record 33 of Set 3 | wuwei
# Processing Record 34 of Set 3 | sibu
# Processing Record 35 of Set 3 | show low
# Processing Record 36 of Set 3 | kirakira
# Processing Record 37 of Set 3 | hobyo
# Processing Record 38 of Set 3 | freeport
# Processing Record 39 of Set 3 | plettenberg bay
# Processing Record 40 of Set 3 | bengbu
# Processing Record 41 of Set 3 | hirara
# Processing Record 42 of Set 3 | alofi
# Processing Record 43 of Set 3 | nantucket
# Processing Record 44 of Set 3 | vao
# Processing Record 45 of Set 3 | olinda
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | andenes
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | zafra
# Processing Record 50 of Set 3 | manakara
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | riyadh
# Processing Record 3 of Set 4 | havoysund
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | biak
# Processing Record 6 of Set 4 | port blair
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | bereda
# Processing Record 10 of Set 4 | warrnambool
# Processing Record 11 of Set 4 | walvis bay
# Processing Record 12 of Set 4 | egvekinot
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | keuruu
# Processing Record 15 of Set 4 | xiaoweizhai
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | bull savanna
# Processing Record 18 of Set 4 | pascagoula
# Processing Record 19 of Set 4 | mehamn
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | hailin
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | port-gentil
# Processing Record 26 of Set 4 | aninoasa
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | renqiu
# Processing Record 29 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 4 | cap-aux-meules
# Processing Record 31 of Set 4 | mmabatho
# Processing Record 32 of Set 4 | alta floresta
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | skjervoy
# Processing Record 36 of Set 4 | gamba
# Processing Record 37 of Set 4 | nador
# Processing Record 38 of Set 4 | aksarka
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | cabra
# Processing Record 42 of Set 4 | sebeta
# Processing Record 43 of Set 4 | srednekolymsk
# Processing Record 44 of Set 4 | weihai
# Processing Record 45 of Set 4 | janakpur road
# City not found. Skipping...
# Processing Record 46 of Set 4 | ribeira brava
# Processing Record 47 of Set 4 | banjar
# Processing Record 48 of Set 4 | nobres
# Processing Record 49 of Set 4 | kysyl-syr
# Processing Record 50 of Set 4 | mathathane
# Processing Record 1 of Set 5 | kushima
# Processing Record 2 of Set 5 | vestmannaeyjar
# Processing Record 3 of Set 5 | nizhniy kuranakh
# Processing Record 4 of Set 5 | khandyga
# Processing Record 5 of Set 5 | mahon
# Processing Record 6 of Set 5 | sorong
# Processing Record 7 of Set 5 | chester
# Processing Record 8 of Set 5 | cap malheureux
# Processing Record 9 of Set 5 | inta
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | toora-khem
# Processing Record 13 of Set 5 | umm lajj
# Processing Record 14 of Set 5 | sisimiut
# Processing Record 15 of Set 5 | fairview
# Processing Record 16 of Set 5 | tarauaca
# Processing Record 17 of Set 5 | tecoanapa
# Processing Record 18 of Set 5 | najran
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | kutum
# Processing Record 22 of Set 5 | coffs harbour
# Processing Record 23 of Set 5 | ostuni
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | bodaybo
# Processing Record 26 of Set 5 | stromness
# Processing Record 27 of Set 5 | mount isa
# Processing Record 28 of Set 5 | saint-philippe
# Processing Record 29 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 5 | sobolevo
# Processing Record 31 of Set 5 | bandarbeyla
# Processing Record 32 of Set 5 | oranjemund
# Processing Record 33 of Set 5 | gusinoye ozero
# Processing Record 34 of Set 5 | salalah
# Processing Record 35 of Set 5 | palmer
# Processing Record 36 of Set 5 | namatanai
# Processing Record 37 of Set 5 | taseyevo
# Processing Record 38 of Set 5 | benicarlo
# Processing Record 39 of Set 5 | victor harbor
# Processing Record 40 of Set 5 | tara
# Processing Record 41 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 5 | benghazi
# Processing Record 43 of Set 5 | borazjan
# Processing Record 44 of Set 5 | lapua
# Processing Record 45 of Set 5 | port macquarie
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | kaspiyskiy
# Processing Record 2 of Set 6 | shieli
# Processing Record 3 of Set 6 | pareora
# Processing Record 4 of Set 6 | ewa beach
# Processing Record 5 of Set 6 | arraial do cabo
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | fortuna
# Processing Record 8 of Set 6 | breytovo
# Processing Record 9 of Set 6 | antofagasta
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | coquimbo
# Processing Record 12 of Set 6 | vagur
# Processing Record 13 of Set 6 | lakatoro
# Processing Record 14 of Set 6 | la crosse
# Processing Record 15 of Set 6 | wanning
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | porto novo
# Processing Record 18 of Set 6 | mareeba
# Processing Record 19 of Set 6 | tezu
# Processing Record 20 of Set 6 | chuy
# Processing Record 21 of Set 6 | southbridge
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 24 of Set 6 | batagay-alyta
# Processing Record 25 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 6 | broken hill
# Processing Record 27 of Set 6 | manubul
# Processing Record 28 of Set 6 | tabuk
# Processing Record 29 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 6 | nelson bay
# Processing Record 31 of Set 6 | boa vista
# Processing Record 32 of Set 6 | nemuro
# Processing Record 33 of Set 6 | leningradskiy
# Processing Record 34 of Set 6 | katima mulilo
# Processing Record 35 of Set 6 | yar-sale
# Processing Record 36 of Set 6 | doha
# Processing Record 37 of Set 6 | kendari
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | ponta do sol
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | vrangel
# Processing Record 42 of Set 6 | kenai
# Processing Record 43 of Set 6 | vila
# Processing Record 44 of Set 6 | saint-michel-des-saints
# Processing Record 45 of Set 6 | jibuti
# Processing Record 46 of Set 6 | nagapattinam
# Processing Record 47 of Set 6 | chokurdakh
# Processing Record 48 of Set 6 | ossora
# Processing Record 49 of Set 6 | buenaventura
# Processing Record 50 of Set 6 | zhezkazgan
# Processing Record 1 of Set 7 | muromtsevo
# Processing Record 2 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 7 | djibo
# Processing Record 4 of Set 7 | monrovia
# Processing Record 5 of Set 7 | atagay
# Processing Record 6 of Set 7 | madison
# Processing Record 7 of Set 7 | otradnoye
# Processing Record 8 of Set 7 | abha
# Processing Record 9 of Set 7 | iguape
# Processing Record 10 of Set 7 | ouesso
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | piacabucu
# Processing Record 14 of Set 7 | upernavik
# Processing Record 15 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 16 of Set 7 | ye
# City not found. Skipping...
# Processing Record 17 of Set 7 | madridejos
# Processing Record 18 of Set 7 | tarakan
# Processing Record 19 of Set 7 | khani
# Processing Record 20 of Set 7 | sarahan
# Processing Record 21 of Set 7 | jumla
# Processing Record 22 of Set 7 | odesskoye
# Processing Record 23 of Set 7 | ankang
# Processing Record 24 of Set 7 | mendi
# Processing Record 25 of Set 7 | barra patuca
# Processing Record 26 of Set 7 | port lincoln
# Processing Record 27 of Set 7 | lingao
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | kaseda
# Processing Record 30 of Set 7 | liwale
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | qostanay
# Processing Record 34 of Set 7 | rocha
# Processing Record 35 of Set 7 | tahta
# Processing Record 36 of Set 7 | coahuayana
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | ulaangom
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | pangai
# Processing Record 41 of Set 7 | lamar
# Processing Record 42 of Set 7 | chalus
# Processing Record 43 of Set 7 | innisfail
# Processing Record 44 of Set 7 | nioro
# Processing Record 45 of Set 7 | saint-joseph
# Processing Record 46 of Set 7 | felipe carrillo puerto
# Processing Record 47 of Set 7 | thongwa
# Processing Record 48 of Set 7 | hargeysa
# Processing Record 49 of Set 7 | cilegon
# Processing Record 50 of Set 7 | sitka
# Processing Record 1 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | kudahuvadhoo
# Processing Record 4 of Set 8 | wainwright
# Processing Record 5 of Set 8 | gaogou
# Processing Record 6 of Set 8 | labuhan
# Processing Record 7 of Set 8 | grand gaube
# Processing Record 8 of Set 8 | portland
# Processing Record 9 of Set 8 | isagarh
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | ozernovskiy
# Processing Record 12 of Set 8 | seoul
# Processing Record 13 of Set 8 | sept-iles
# Processing Record 14 of Set 8 | praia da vitoria
# Processing Record 15 of Set 8 | clyde river
# Processing Record 16 of Set 8 | ancud
# Processing Record 17 of Set 8 | jevargi
# Processing Record 18 of Set 8 | roald
# Processing Record 19 of Set 8 | hualmay
# Processing Record 20 of Set 8 | sikonge
# Processing Record 21 of Set 8 | naze
# Processing Record 22 of Set 8 | avera
# Processing Record 23 of Set 8 | katherine
# Processing Record 24 of Set 8 | adrar
# Processing Record 25 of Set 8 | maarianhamina
# Processing Record 26 of Set 8 | bathsheba
# Processing Record 27 of Set 8 | raga
# Processing Record 28 of Set 8 | thompson
# Processing Record 29 of Set 8 | nizhniy odes
# Processing Record 30 of Set 8 | poronaysk
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | bamiantong
# Processing Record 33 of Set 8 | sao filipe
# Processing Record 34 of Set 8 | nhulunbuy
# Processing Record 35 of Set 8 | kruisfontein
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | ferndale
# Processing Record 38 of Set 8 | cherskiy
# Processing Record 39 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 8 | yumen
# Processing Record 41 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 8 | cockburn town
# Processing Record 43 of Set 8 | carmen del parana
# Processing Record 44 of Set 8 | georgetown
# Processing Record 45 of Set 8 | puerto carreno
# Processing Record 46 of Set 8 | misratah
# Processing Record 47 of Set 8 | gorgan
# Processing Record 48 of Set 8 | muswellbrook
# Processing Record 49 of Set 8 | orlik
# Processing Record 50 of Set 8 | maumere
# Processing Record 1 of Set 9 | polis
# Processing Record 2 of Set 9 | piterka
# Processing Record 3 of Set 9 | staryy nadym
# Processing Record 4 of Set 9 | morogoro
# Processing Record 5 of Set 9 | boras
# Processing Record 6 of Set 9 | gushikawa
# Processing Record 7 of Set 9 | klyuchi
# Processing Record 8 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 9 | tual
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | bozeman
# Processing Record 12 of Set 9 | buala
# Processing Record 13 of Set 9 | romanovka
# Processing Record 14 of Set 9 | athabasca
# Processing Record 15 of Set 9 | yeppoon
# Processing Record 16 of Set 9 | neyshabur
# Processing Record 17 of Set 9 | rio grande
# Processing Record 18 of Set 9 | gidam
# Processing Record 19 of Set 9 | wajima
# Processing Record 20 of Set 9 | esso
# Processing Record 21 of Set 9 | mahebourg
# Processing Record 22 of Set 9 | waipawa
# Processing Record 23 of Set 9 | springbok
# Processing Record 24 of Set 9 | vallenar
# Processing Record 25 of Set 9 | bonthe
# Processing Record 26 of Set 9 | port hardy
# Processing Record 27 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 9 | rabo de peixe
# Processing Record 29 of Set 9 | lensk
# Processing Record 30 of Set 9 | porto alegre
# Processing Record 31 of Set 9 | road town
# Processing Record 32 of Set 9 | okhotsk
# Processing Record 33 of Set 9 | daru
# Processing Record 34 of Set 9 | bambous virieux
# Processing Record 35 of Set 9 | nichinan
# Processing Record 36 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 9 | coihaique
# Processing Record 38 of Set 9 | aden
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | buin
# Processing Record 41 of Set 9 | mastic beach
# Processing Record 42 of Set 9 | donskoye
# Processing Record 43 of Set 9 | arlit
# Processing Record 44 of Set 9 | erice
# Processing Record 45 of Set 9 | vanimo
# Processing Record 46 of Set 9 | cedar city
# Processing Record 47 of Set 9 | mwanza
# Processing Record 48 of Set 9 | ilulissat
# Processing Record 49 of Set 9 | lasa
# Processing Record 50 of Set 9 | maniitsoq
# Processing Record 1 of Set 10 | mvuma
# Processing Record 2 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 3 of Set 10 | kashan
# Processing Record 4 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 5 of Set 10 | deception bay
# Processing Record 6 of Set 10 | belaya gora
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | tarko-sale
# Processing Record 9 of Set 10 | saldanha
# Processing Record 10 of Set 10 | partizanskoye
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | san luis
# Processing Record 13 of Set 10 | eyl
# Processing Record 14 of Set 10 | mantua
# Processing Record 15 of Set 10 | linjiang
# Processing Record 16 of Set 10 | sergeyevka
# Processing Record 17 of Set 10 | matara
# Processing Record 18 of Set 10 | itaqui
# Processing Record 19 of Set 10 | ballina
# Processing Record 20 of Set 10 | griffith
# Processing Record 21 of Set 10 | kibala
# Processing Record 22 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 10 | octeville
# Processing Record 24 of Set 10 | raurkela
# City not found. Skipping...
# Processing Record 25 of Set 10 | rabak
# Processing Record 26 of Set 10 | saint-augustin
# Processing Record 27 of Set 10 | piney green
# Processing Record 28 of Set 10 | am timan
# Processing Record 29 of Set 10 | tucuman
# Processing Record 30 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 10 | cidreira
# Processing Record 32 of Set 10 | acari
# Processing Record 33 of Set 10 | bismarck
# Processing Record 34 of Set 10 | bone
# Processing Record 35 of Set 10 | cascais
# Processing Record 36 of Set 10 | ponta delgada
# Processing Record 37 of Set 10 | richards bay
# Processing Record 38 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 39 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 40 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 10 | ishim
# Processing Record 42 of Set 10 | hofn
# Processing Record 43 of Set 10 | tacuarembo
# Processing Record 44 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 10 | prince rupert
# Processing Record 46 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 10 | siguiri
# Processing Record 48 of Set 10 | kaduy
# Processing Record 49 of Set 10 | helena
# Processing Record 50 of Set 10 | okakarara
# Processing Record 1 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 11 | lethem
# Processing Record 3 of Set 11 | methoni
# Processing Record 4 of Set 11 | conceicao da barra
# Processing Record 5 of Set 11 | port augusta
# Processing Record 6 of Set 11 | gorom-gorom
# Processing Record 7 of Set 11 | beysehir
# Processing Record 8 of Set 11 | nacala
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | butembo
# Processing Record 11 of Set 11 | college
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | maldonado
# Processing Record 14 of Set 11 | burica
# City not found. Skipping...
# Processing Record 15 of Set 11 | remontnoye
# Processing Record 16 of Set 11 | sanjwal
# Processing Record 17 of Set 11 | santa catarina de tepehuanes
# Processing Record 18 of Set 11 | samarai
# Processing Record 19 of Set 11 | imeni poliny osipenko
# Processing Record 20 of Set 11 | itarema
# Processing Record 21 of Set 11 | songjianghe
# Processing Record 22 of Set 11 | soc trang
# Processing Record 23 of Set 11 | qasigiannguit
# Processing Record 24 of Set 11 | lata
# Processing Record 25 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 11 | toulepleu
# City not found. Skipping...
# Processing Record 27 of Set 11 | lokosovo
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | sao joao da barra
# Processing Record 30 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 31 of Set 11 | nago
# Processing Record 32 of Set 11 | hay river
# Processing Record 33 of Set 11 | berbera
# Processing Record 34 of Set 11 | mokhsogollokh
# Processing Record 35 of Set 11 | alexandria
# Processing Record 36 of Set 11 | ukiah
# Processing Record 37 of Set 11 | pa sang
# Processing Record 38 of Set 11 | ambilobe
# Processing Record 39 of Set 11 | newport
# Processing Record 40 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 11 | huarmey
# Processing Record 42 of Set 11 | ulladulla
# Processing Record 43 of Set 11 | paita
# Processing Record 44 of Set 11 | khorixas
# Processing Record 45 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 11 | copiapo
# Processing Record 47 of Set 11 | brovst
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | horta
# Processing Record 50 of Set 11 | kedrovyy
# Processing Record 1 of Set 12 | paoua
# Processing Record 2 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 3 of Set 12 | dwarka
# Processing Record 4 of Set 12 | poso
# Processing Record 5 of Set 12 | sabaudia
# Processing Record 6 of Set 12 | henties bay
# Processing Record 7 of Set 12 | moberly
# Processing Record 8 of Set 12 | mach
# Processing Record 9 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 12 | tlacotepec
# Processing Record 11 of Set 12 | anadyr
# Processing Record 12 of Set 12 | loyga
# Processing Record 13 of Set 12 | nalut
# Processing Record 14 of Set 12 | santa cruz
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | calama
# Processing Record 17 of Set 12 | tra vinh
# Processing Record 18 of Set 12 | batagay
# Processing Record 19 of Set 12 | comodoro rivadavia
# Processing Record 20 of Set 12 | camabatela
# Processing Record 21 of Set 12 | prainha
# Processing Record 22 of Set 12 | santa vitoria do palmar
# Processing Record 23 of Set 12 | port hedland
# Processing Record 24 of Set 12 | bethanien
# Processing Record 25 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | chimay
# Processing Record 28 of Set 12 | ailigandi
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | dhilwan
# Processing Record 31 of Set 12 | feldkirchen
# Processing Record 32 of Set 12 | moose factory
# Processing Record 33 of Set 12 | mianwali
# Processing Record 34 of Set 12 | warrington
# Processing Record 35 of Set 12 | pafos
# Processing Record 36 of Set 12 | phuket
# Processing Record 37 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 39 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 12 | charters towers
# Processing Record 41 of Set 12 | beloretsk
# Processing Record 42 of Set 12 | sungaipenuh
# Processing Record 43 of Set 12 | evensk
# Processing Record 44 of Set 12 | verkhnyaya inta
# Processing Record 45 of Set 12 | fare
# Processing Record 46 of Set 12 | los llanos de aridane
# Processing Record 47 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 12 | bonfim
# Processing Record 50 of Set 12 | salym
# Processing Record 1 of Set 13 | kawalu
# Processing Record 2 of Set 13 | kulhudhuffushi
# Processing Record 3 of Set 13 | constitucion
# Processing Record 4 of Set 13 | arona
# Processing Record 5 of Set 13 | krasnomayskiy
# Processing Record 6 of Set 13 | tessalit
# Processing Record 7 of Set 13 | porbandar
# Processing Record 8 of Set 13 | saint-alexandre
# Processing Record 9 of Set 13 | sire
# Processing Record 10 of Set 13 | sorland
# Processing Record 11 of Set 13 | gold coast
# Processing Record 12 of Set 13 | paka
# Processing Record 13 of Set 13 | kroya
# Processing Record 14 of Set 13 | torbay
# Processing Record 15 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 13 | fallon
# Processing Record 17 of Set 13 | perth
# Processing Record 18 of Set 13 | marawi
# Processing Record 19 of Set 13 | ranau
# Processing Record 20 of Set 13 | sao jose da coroa grande
# Processing Record 21 of Set 13 | powell river
# Processing Record 22 of Set 13 | ayr
# Processing Record 23 of Set 13 | baykit
# Processing Record 24 of Set 13 | machiques
# Processing Record 25 of Set 13 | san juan del sur
# Processing Record 26 of Set 13 | mahibadhoo
# Processing Record 27 of Set 13 | akodia
# Processing Record 28 of Set 13 | pangnirtung
# Processing Record 29 of Set 13 | jamame
# Processing Record 30 of Set 13 | inhambane
# Processing Record 31 of Set 13 | neryungri
# Processing Record 32 of Set 13 | mabaruma
# Processing Record 33 of Set 13 | olafsvik
# Processing Record 34 of Set 13 | shingu
# Processing Record 35 of Set 13 | karnal
# Processing Record 36 of Set 13 | beloha
# Processing Record 37 of Set 13 | te anau
# Processing Record 38 of Set 13 | valle de guadalupe
# Processing Record 39 of Set 13 | kerava
# Processing Record 40 of Set 13 | benguela
# Processing Record 41 of Set 13 | dotnuva
# Processing Record 42 of Set 13 | bayanday
# Processing Record 43 of Set 13 | sananduva
# Processing Record 44 of Set 13 | jacareacanga
# Processing Record 45 of Set 13 | mangrol
# Processing Record 46 of Set 13 | jinzhou
# Processing Record 47 of Set 13 | gardez
# Processing Record 48 of Set 13 | meadow lake
# Processing Record 49 of Set 13 | aswan
# Processing Record 50 of Set 13 | kalmunai
# Processing Record 1 of Set 14 | bang saphan
# Processing Record 2 of Set 14 | cabedelo
# Processing Record 3 of Set 14 | nyiracsad
# Processing Record 4 of Set 14 | watertown
# Processing Record 5 of Set 14 | temanggung
# Processing Record 6 of Set 14 | gelibolu
# Processing Record 7 of Set 14 | serenje
# Processing Record 8 of Set 14 | carutapera
# Processing Record 9 of Set 14 | palora
# Processing Record 10 of Set 14 | tilichiki
# Processing Record 11 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 12 of Set 14 | nizwa
# Processing Record 13 of Set 14 | zacler
# Processing Record 14 of Set 14 | luau
# Processing Record 15 of Set 14 | majene
# Processing Record 16 of Set 14 | kamaishi
# Processing Record 17 of Set 14 | reconquista
# Processing Record 18 of Set 14 | besikduzu
# Processing Record 19 of Set 14 | zabid
# Processing Record 20 of Set 14 | teguldet
# Processing Record 21 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 22 of Set 14 | gazli
# Processing Record 23 of Set 14 | lincoln
# Processing Record 24 of Set 14 | jatai
# Processing Record 25 of Set 14 | ola
# Processing Record 26 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 14 | opuwo
# Processing Record 28 of Set 14 | marzuq
# Processing Record 29 of Set 14 | varna
# Processing Record 30 of Set 14 | guatire
# Processing Record 31 of Set 14 | marmaris
# Processing Record 32 of Set 14 | biggar
# Processing Record 33 of Set 14 | minot
# Processing Record 34 of Set 14 | palmas
# Processing Record 35 of Set 14 | port moresby
# Processing Record 36 of Set 14 | bjornevatn
# Processing Record 37 of Set 14 | obo
# Processing Record 38 of Set 14 | ostrovnoy
# Processing Record 39 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 14 | hambantota
# Processing Record 41 of Set 14 | santa luzia
# Processing Record 42 of Set 14 | karabanovo
# Processing Record 43 of Set 14 | hovd
# Processing Record 44 of Set 14 | ahipara
# Processing Record 45 of Set 14 | pierre
# Processing Record 46 of Set 14 | bustonkala
# City not found. Skipping...
# Processing Record 47 of Set 14 | malanje
# Processing Record 48 of Set 14 | chara
# Processing Record 49 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 50 of Set 14 | lazaro cardenas
# Processing Record 1 of Set 15 | meridian
# Processing Record 2 of Set 15 | shihezi
# Processing Record 3 of Set 15 | mosquera
# Processing Record 4 of Set 15 | el sauce
# Processing Record 5 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 15 | pudozh
# Processing Record 7 of Set 15 | jalu
# Processing Record 8 of Set 15 | san francisco de coray
# Processing Record 9 of Set 15 | priargunsk
# Processing Record 10 of Set 15 | omurtag
# Processing Record 11 of Set 15 | smidovich
# Processing Record 12 of Set 15 | dehloran
# Processing Record 13 of Set 15 | dudinka
# Processing Record 14 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 15 of Set 15 | price
# Processing Record 16 of Set 15 | zarubino
# Processing Record 17 of Set 15 | caramay
# Processing Record 18 of Set 15 | hervey bay
# Processing Record 19 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 20 of Set 15 | esterhazy
# Processing Record 21 of Set 15 | lianzhou
# Processing Record 22 of Set 15 | grand-lahou
# Processing Record 23 of Set 15 | freetown
# Processing Record 24 of Set 15 | luan
# Processing Record 25 of Set 15 | vardo
# Processing Record 26 of Set 15 | baruun-urt
# Processing Record 27 of Set 15 | hami
# Processing Record 28 of Set 15 | arua
# Processing Record 29 of Set 15 | dmitriyevka
# Processing Record 30 of Set 15 | pangkalanbuun
# Processing Record 31 of Set 15 | ikalamavony
# Processing Record 32 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 15 | santa clara
# Processing Record 34 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 15 | miri
# Processing Record 36 of Set 15 | campbellton
# Processing Record 37 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 15 | tanout
# Processing Record 39 of Set 15 | ambositra
# Processing Record 40 of Set 15 | sens
# Processing Record 41 of Set 15 | porto torres
# Processing Record 42 of Set 15 | jacmel
# Processing Record 43 of Set 15 | lubango
# Processing Record 44 of Set 15 | pavilosta
# Processing Record 45 of Set 15 | bend
# Processing Record 46 of Set 15 | dubbo
# Processing Record 47 of Set 15 | babati
# Processing Record 48 of Set 15 | pochutla
# Processing Record 49 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 1 of Set 16 | ilula
# Processing Record 2 of Set 16 | puerto baquerizo moreno
# Processing Record 3 of Set 16 | rovaniemi
# Processing Record 4 of Set 16 | suzun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mataura -46.1927  168.8643     43.88        90          99       14.76
# 1      Ushuaia -54.8000  -68.3000     44.26        70          75        5.75
# 2    Esperance -33.8667  121.9000     67.15        59          14        6.04
# 3     Imbituba -28.2400  -48.6703     59.86        98           4        3.49
# 4      Russell  32.3502  -85.1999     78.03        83           0        0.00
# 5       Hobart -42.8794  147.3294     52.27        80          20       10.36
# 6         Poum -20.2333  164.0167     78.12        81           2        7.16
# 7        Pevek  69.7008  170.3133     33.31        99          83        5.39
# 8        Bluff -46.6000  168.3333     46.90        76          98       35.81
# 9  Maple Creek  49.9168 -109.4848     46.45        42         100        9.22
#
#   Country City Description
# 0      NZ  overcast clouds
# 1      AR    broken clouds
# 2      AU       few clouds
# 3      BR        clear sky
# 4      US        clear sky
# 5      AU       few clouds
# 6      NC        clear sky
# 7      RU    broken clouds
# 8      NZ  overcast clouds
# 9      CA  overcast clouds

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file)
